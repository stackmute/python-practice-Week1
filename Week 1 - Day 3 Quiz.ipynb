# %% [markdown]
# # Week 1 - Day 3 Quiz
# # list & dictionary practice

# %%
prices=[1000, 2500, 3000]

print(1000+2500+3000)
# Out:
# 6500

# %% [markdown]
# prices=[1000, 2500, 3000]
#
# #total=0
# #for price in prices:
#     #total=total+price
#
# print(total)

# %%
product={
    "name":"Laptop",
    "price":1200000,
    "stock":5
}


print(product)
# Out:
# {'name': 'Laptop', 'price': 1200000, 'stock': 5}

# %% [markdown]
# product={
#     "name":"Laptop",
#     "price":1200000,
#     "stock":5
# }
#
# #for key in product:
#     #print(product[key])

# %%
product={
    "name":"Laptop",
    "price":1200000,
    "stock":5
}

if stock>=1:
    print("판매 가능")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 7
#       1 product={
#       2     "name":"Laptop",
#       3     "price":1200000,
#       4     "stock":5
#       5 }
# ----> 7 if stock>=1:
#       8     print("판매 가능")
#
# NameError: name 'stock' is not defined

# %% [markdown]
# product={
#     "name":"Laptop",
#     "price":1200000,
#     "stock":5
# }
#
# if #product["stock"]>=1:
#     print("판매 가능")
