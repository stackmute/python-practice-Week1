# %% [markdown]
# # Week 1 - Day 5
# # CSV file & pandas basic

# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv.txt")
print(df)
# Out:
#       name  score
# 0    Alice     85
# 1      Bob     72
# 2  Charlie     90
# 3    David     60

# %%
print(df["score"])
# Out:
# 0    85
# 1    72
# 2    90
# 3    60
# Name: score, dtype: int64

# %%
high_score = df[df["score"] >= 80]
print(high_score)
# Out:
#       name  score
# 0    Alice     85
# 2  Charlie     90

# %%
print(df["score"].mean())
print(df["score"].max())
print(df["score"].min())
# Out:
# 76.75
# 90
# 60
