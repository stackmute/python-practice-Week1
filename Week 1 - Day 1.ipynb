# %% [markdown]
# # Week 1 - Day 1
# # Python basic practice

# %%
print("Hello Python")
# Out:
# Hello Python

# %%
print(10)
print(3.14)
# Out:
# 10
# 3.14

# %%
print(10 + 5)
print(10 - 5)
print(10 * 5)
print(10 / 5)
# Out:
# 15
# 5
# 50
# 2.0

# %%
a = 10
b = 3

print(a + b)
print(a * b)
# Out:
# 13
# 30

# %%
name = "Python"
print(name)
# Out:
# Python
