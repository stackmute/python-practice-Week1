# %% [markdown]
# # Week 1 - Day 5 Quiz
# # CSV file & pandas basic

# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv.txt")
print(df)
# Out:
#       name  score
# 0    Alice     85
# 1      Bob     72
# 2  Charlie     90
# 3    David     60

# %%
print(df["score"].mean())
# Out:
# 76.75

# %%
high_score = df[df["score"] >= 70]
print(high_score)
# Out:
#       name  score
# 0    Alice     85
# 1      Bob     72
# 2  Charlie     90
