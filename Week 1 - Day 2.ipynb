# %% [markdown]
# # Week 1 - Day 2
# # if / for practice

# %%
score=85

if score>=60:
    print("Pass")
# Out:
# Pass

# %%
score=40

if score>=60:
    print("Pass")
else:
    print("Fail")
# Out:
# Fail

# %%
x=10

print(x>5)
print(x==10)
print(x<3)
# Out:
# True
# True
# False

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
total=0

for i in range(1,6):
    total=total+i

print(total)
# Out:
# 15

# %%
for i in range(1,11):
    if i % 2==0:
        print(i)
# Out:
# 2
# 4
# 6
# 8
# 10
