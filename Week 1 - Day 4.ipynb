# %% [markdown]
# # Week 1 - Day 4
# # Function (def) practice

# %%
a=10
b=20
print(a+b)

a=5
b=7
print(a+b)
# Out:
# 30
# 12

# %%
def add(x,y):
    result=x+y
    return result

print(add(10,20))
print(add(5,7))
# Out:
# 30
# 12

# %%
add(3,4)
# Out:
# 7

# %%
def say_hello(name):
    print("Hello",name) 

say_hello("Phyton")
say_hello("Jupyter")
# Out:
# Hello Phyton
# Hello Jupyter

# %%
def check_pass(score):
    if score >=60:
        return "Pass"
    else:
        return "Fail"

print(check_pass(80))
print(check_pass(45))
# Out:
# Pass
# Fail
