# %% [markdown]
# # Week 1 - Day 4 Quiz
# # Function (def) practice

# %%
def multiply(x,y):
    result=x*y
    return result

print(add(10,20))
print(add(5,7))
# Out:
# 200
# 35

# %%
def grade(score):
    if score >=90:
        return "A"
    if score >=60:
        return "B"
    else:
        return "C"

print(check_pass(90))
print(check_pass(80))
print(check_pass(45))
# Out:
# A
# B
# C
