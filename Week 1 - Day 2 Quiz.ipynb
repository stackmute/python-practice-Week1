# %% [markdown]
# # Week 1 - Day 2 Quiz
# # if / for practice

# %%
for i in range(1,10):
    if i % 3==0:
        print(i)
# Out:
# 3
# 6
# 9

# %%
score=[45, 72, 88, 59, 90]

if score>=60:
# Out:
#   Cell In[2], line 3
#     if score>=60:
#                  ^
# _IncompleteInputError: incomplete input

# %%
scores=[45, 72, 88, 59, 90]

for score in scores:
    if score>=60:
        print(score)
# Out:
# 72
# 88
# 90

# %% [markdown]
# #for score in scores
# → so that I can print out the desired value among the different scores
# #print(score)
