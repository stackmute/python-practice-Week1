# %% [markdown]
# # Week 1 - Day 1 Quiz
# # Python basic practice

# %%
x=12
y=5

print(x+y)
print(x*y)
# Out:
# 17
# 60

# %%
name="Phyton is fun!"
print(name)
# Out:
# Phyton is fun!

# %%
name="Jupyter"
print("I am using", name)
# Out:
# I am using Jupyter
