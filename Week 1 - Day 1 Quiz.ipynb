# %% [markdown]
# # Week 1 - Day 1 Quiz
# # Python basic practice

# %%
x=12
y=5

print(x+y)
print(x*y)
# Out:
# 17
# 60

# %%
name="Phyton is fun!"
print(name)
# Out:
# Phyton is fun!

# %%
name="Jupyter"
print("I am using", name)
# Out:
# I am using Jupyter

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\mmini\\기초\\python-practice-Week 1'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'data.csv.txt',
#  'result.csv.txt',
#  'Week 1 - Day 1 Quiz.ipynb',
#  'Week 1 - Day 1.ipynb',
#  'Week 1 - Day 2 Quiz.ipynb',
#  'Week 1 - Day 2.ipynb',
#  'Week 1 - Day 3 Quiz.ipynb',
#  'Week 1 - Day 3.ipynb',
#  'Week 1 - Day 4 Quiz.ipynb',
#  'Week 1 - Day 4.ipynb',
#  'Week 1 - Day 5.ipynb',
#  'Week 1 - Day 6 Quiz.ipynb',
#  'Week 1 - Day 6.ipynb',
#  'Week 1- Day 5 Quiz.ipynb']
